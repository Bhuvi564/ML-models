# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhuvi564/ML-models/blob/main/Random_Forest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data_set = pd.read_csv("accenture.csv")
X = data_set.iloc[:, 1:-1].values
y = data_set.iloc[:, -1].values

# %%
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators= 12 ,random_state = 5)
regressor.fit(X,y)
# Out:
# RandomForestRegressor(n_estimators=12, random_state=5)

# %%
regressor.predict([[5]])
# Out:
# array([85416.66666667])

# %%
X_grid = np.arange(min(X), max(X), 0.01)
X_grid = X_grid.reshape(len(X_grid), 1)
plt.scatter(X, y, color = 'red')
plt.plot(X_grid, regressor.predict(X_grid), color = 'blue')
plt.title("Random Forest Algorithm")
plt.xlabel("Position")
plt.ylabel("Salary")
plt.show()
# Out:
# <ipython-input-12-fadb796e4e3e>:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   X_grid = np.arange(min(X), max(X), 0.01)

# %%
from sklearn.metrics import r2_score
r2_score(y, regressor.predict(X))
# Out:
# 0.9572509677053175
