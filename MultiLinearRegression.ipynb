# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhuvi564/SimpleLinearRegression-ML-model/blob/main/MultiLinearRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data_set = pd.read_csv("covid.csv")
X = data_set.iloc[ : , :-1].values
y = data_set.iloc[: , -1].values

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
ct = ColumnTransformer(transformers = [('encoder', OneHotEncoder(), [1])], remainder = "passthrough")
X = np.array(ct.fit_transform(X))

# %%
print(X)
# Out:
# [[0.0 0.0 1.0 10 0 97]
#  [1.0 0.0 0.0 80 0 92]
#  [0.0 1.0 0.0 10 0 97]
#  [1.0 0.0 0.0 81 4 75]
#  [0.0 0.0 1.0 12 0 97]
#  [0.0 1.0 0.0 18 0 66]
#  [0.0 0.0 1.0 13 0 93]
#  [1.0 0.0 0.0 94 4 64]
#  [1.0 0.0 0.0 86 2 76]
#  [0.0 0.0 1.0 20 0 92]
#  [0.0 0.0 1.0 15 0 94]
#  [0.0 0.0 1.0 15 0 92]
#  [0.0 1.0 0.0 16 0 92]
#  [0.0 0.0 1.0 17 0 93]
#  [0.0 0.0 1.0 18 0 93]
#  [0.0 0.0 1.0 19 0 92]
#  [0.0 0.0 1.0 19 0 89]
#  [0.0 0.0 1.0 12 0 97]
#  [0.0 0.0 1.0 20 0 93]
#  [0.0 0.0 1.0 24 0 92]
#  [0.0 0.0 1.0 25 0 93]
#  [1.0 0.0 0.0 59 2 68]
#  [1.0 0.0 0.0 63 1 66]
#  [0.0 0.0 1.0 25 1 62]
#  [1.0 0.0 0.0 26 0 94]
#  [0.0 1.0 0.0 26 0 97]
#  [0.0 0.0 1.0 28 0 99]
#  [1.0 0.0 0.0 59 0 69]
#  [0.0 0.0 1.0 28 0 89]
#  [0.0 0.0 1.0 29 0 93]
#  [0.0 0.0 1.0 48 0 93]
#  [0.0 0.0 1.0 30 0 62]
#  [0.0 0.0 1.0 30 0 86]
#  [0.0 0.0 1.0 32 0 84]
#  [0.0 0.0 1.0 34 1 90]
#  [0.0 0.0 1.0 35 0 89]
#  [1.0 0.0 0.0 50 2 77]
#  [1.0 0.0 0.0 56 2 76]
#  [1.0 0.0 0.0 56 1 77]
#  [1.0 0.0 0.0 36 1 90]
#  [1.0 0.0 0.0 38 2 75]
#  [0.0 0.0 1.0 40 0 90]
#  [1.0 0.0 0.0 40 0 92]
#  [1.0 0.0 0.0 61 2 76]
#  [1.0 0.0 0.0 42 0 92]
#  [1.0 0.0 0.0 46 0 91]
#  [0.0 0.0 1.0 49 0 80]
#  [1.0 0.0 0.0 52 1 80]
#  [0.0 0.0 1.0 32 0 89]
#  [1.0 0.0 0.0 53 1 55]
#  [1.0 0.0 0.0 54 1 70]
#  [1.0 0.0 0.0 90 3 67]
#  [1.0 0.0 0.0 78 2 71]
#  [1.0 0.0 0.0 58 0 70]
#  [1.0 0.0 0.0 60 1 68]
#  [0.0 0.0 1.0 61 0 90]
#  [1.0 0.0 0.0 62 1 68]
#  [1.0 0.0 0.0 86 3 71]
#  [1.0 0.0 0.0 62 2 69]
#  [1.0 0.0 0.0 64 1 73]
#  [1.0 0.0 0.0 68 1 67]
#  [1.0 0.0 0.0 69 0 53]
#  [0.0 0.0 1.0 70 1 88]
#  [1.0 0.0 0.0 74 2 75]
#  [1.0 0.0 0.0 75 1 72]
#  [1.0 0.0 0.0 76 4 80]
#  [0.0 0.0 1.0 35 0 92]
#  [0.0 0.0 1.0 13 0 94]
#  [1.0 0.0 0.0 82 3 73]
#  [1.0 0.0 0.0 84 3 75]]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.4, random_state = 2)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(X_test)
np.set_printoptions(precision = 3)
print(np.concatenate((y_pred.reshape(len(y_pred), 1), y_test.reshape(len(y_test), 1)), 1))
# Out:
# [[ 55287.887  59010.   ]
#  [ 62237.416  61004.   ]
#  [ 93422.776  93091.   ]
#  [ 81957.824  84008.   ]
#  [ 53455.201  57019.   ]
#  [ 60501.914  62019.   ]
#  [ 60450.259  62001.   ]
#  [ 90841.59   91002.   ]
#  [ 59314.56   61018.   ]
#  [ 89267.037  90124.   ]
#  [ 80200.933  78010.   ]
#  [ 50648.045  59913.   ]
#  [107825.848 127181.   ]
#  [ 91048.068  91019.   ]
#  [103463.631 101000.   ]
#  [ 84797.143  87005.   ]
#  [ 64018.587  66019.   ]
#  [102520.656  99008.   ]
#  [104650.985 112101.   ]
#  [ 94687.542  92101.   ]
#  [ 68161.795  71019.   ]
#  [ 86763.262  87019.   ]
#  [ 99566.024  98101.   ]
#  [ 83407.678  83891.   ]
#  [101811.666  99910.   ]
#  [100030.635  97101.   ]
#  [ 46324.812  45019.   ]
#  [101217.989  99004.   ]]

# %%
plt.plot(y_pred)
plt.plot(y_test)
plt.show()
